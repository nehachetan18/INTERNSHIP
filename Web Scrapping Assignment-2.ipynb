# %%
# !pip install selenium

# %%
#Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You
#have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10
#jobs data.
#This task will be done in following steps:
#1. First get the webpage https://www.shine.com/
#2. Enter “Data Analyst” in “Job title, Skills” field and enter “Bangalore” in “enter the location” field.
#3. Then click the searchbutton.
#4. Then scrape the data for the first 10 jobs results you get.
#5. Finally create a dataframe of the scraped data
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.shine.com/")

# %%
job_title=driver.find_element(By.CLASS_NAME,"form-control")
job_title.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"searchForm_btnWrap_advance__VYBHN")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
#scraping job title
title_tags=driver.find_elements(By.XPATH,'//h2[@itemprop="name"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
#scraping job location
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
#scraping company name
company_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
#scraping job experience
experience_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name,'Experience':experience_required})
df
# Out:
#                                                Title       Location  \
# 0
# 1       Position for- Ruby on Rails Application Lead        Chennai
# 2  SAP for Utilities Energy Data Management Devic...    Mumbai City
# 3                    apply now Application Developer        Chennai
# 4
# 5
# 6
# 7  Opening for Technical Lead Dot Net Remote Loca...  Bangalore\n+2
# 8             Urgent Opening UI/UX Designer in Delhi          Delhi
# 9                                  Flutter Developer     Indore\n+1
#
#                              Company_name   Experience
# 0
# 1                               accenture   4 to 6 Yrs
# 2                               accenture   4 to 6 Yrs
# 3                               accenture   4 to 6 Yrs
# 4
# 5
# 6
# 7  talent max hr & mangagement consult...  6 to 11 Yrs
# 8                      sharda it services   2 to 7 Yrs
# 9  talent max hr & mangagement consult...   4 to 8 Yrs

# %%
#Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
#This task will be done in following steps:
#1. First get the webpage https://www.shine.com/
#2. Enter “Data Scientist” in “Job title, Skills” field and enter “Bangalore” in “enter the location” field.
#3. Then click the search button.
#4. Then scrape the data for the first 10 jobs results you get.
#5. Finally create a dataframe of the scraped data.
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.shine.com/")

# %%
job_title=driver.find_element(By.CLASS_NAME,"form-control")
job_title.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"searchForm_btnWrap_advance__VYBHN")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
#scraping job title
title_tags=driver.find_elements(By.XPATH,'//h2[@itemprop="name"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
#scraping job location
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
#scraping company name
company_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
#scraping job experience
experience_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name,'Experience':experience_required})
df
# Out:
#                                           Title        Location  \
# 0                                Data Scientist       Bangalore
# 1                            SR. DATA SCIENTIST       Bangalore
# 2            Senior Data Scientist- ML Engineer       Bangalore
# 3  Data Scientist Hiring Fresher and Experience  Bangalore\n+17
# 4                            Data Scientist III       Bangalore
# 5                                Data Scientist   Bangalore\n+6
# 6                    Senior Data Scientist, AWS       Bangalore
# 7                    Data Scientist Recruitment  Bangalore\n+17
# 8                     Hiring For Data Scientist  Bangalore\n+17
# 9                     Hiring For Data Scientist  Bangalore\n+17
#
#                     Company_name    Experience
# 0              the fashion cosmo    0 to 4 Yrs
# 1  te connectivity india pvt ltd    5 to 7 Yrs
# 2              sap india pvt ltd    5 to 7 Yrs
# 3       kavya staffing solutions    0 to 4 Yrs
# ...

# %%
#Q3: In this question you have to scrape data using the filters available on the webpage
#You have to use the location and salary filter.
#You have to scrape data for “Data Scientist” designation for first 10 job results.
#You have to scrape the job-title, job-location, company name, experience required. The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs
#The task will be done as shown in the below steps:
#1. first get the web page https://www.shine.com/
#2. Enter “Data Scientist” in “Skill, Designations, and Companies” field.
#3. Then click the search button.
#4. Then apply the location filter and salary filter by checking the respective boxes
#5. Then scrape the data for the first 10 jobs results you get.
#6. Finally create a dataframe of the scraped data.
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.shine.com/")

# %%
job_title=driver.find_element(By.CLASS_NAME,"form-control")
job_title.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input")
location.send_keys('Delhi/NCR')

# %%
search=driver.find_element(By.CLASS_NAME,"searchForm_btnWrap_advance__VYBHN")
search.click()

# %%
salary_checkbox = driver.find_element(By.XPATH, "/html/body/div[1]/div[1]/div[4]/div/div[1]/div/div[2]/div[2]/div/div/div/div[3]/div/div/div/ul/li[3]/span/label")
salary_checkbox.click()

# %%
show_result=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[4]/div/div[1]/div/div[2]/div[2]/div/div/div/div[4]/button[2]")
show_result.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
#scraping job title
title_tags=driver.find_elements(By.XPATH,'//h2[@itemprop="name"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
#scraping job location
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
#scraping company name
company_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
#scraping job experience
experience_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name,'Experience':experience_required})
df
# Out:
#                                                Title        Location  \
# 0                                     Data Scientist       Bangalore
# 1                 Hire DATA SCIENTIST- MIS EXECUTIVE     Mumbai City
# 2        Need now for Data Scientist - MIS Executive     Mumbai City
# 3                  need Data Scientist MIS Executive     Mumbai City
# 4   Urgently Required Data Scientist - MIS Executive     Mumbai City
# 5  Associate Divisional Manager Data Scientist Ch...         Chennai
# 6                                 SR. DATA SCIENTIST       Bangalore
# 7                 Senior Data Scientist- ML Engineer       Bangalore
# 8       Data Scientist Hiring Fresher and Experience  Singapore\n+16
# 9       Data Scientist Hiring Fresher and Experience     Canada\n+17
#
#                         Company_name   Experience
# 0                  the fashion cosmo   0 to 4 Yrs
# 1         h k jewels private limited   4 to 6 Yrs
# 2         h k jewels private limited   4 to 6 Yrs
# ...

# %%
#Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
#6. Brand
#7. Product Description
#8. Price
#The attributes which you have to scrape is ticked marked in the below image
#To scrape the data you have to go through following steps:
#1. Go to Flipkart webpage by url : https://www.flipkart.com/
#2. Enter “sunglasses” in the search field where “search for products, brands and more” is written and click the search icon
#3. After that you will reach to the page having a lot of sunglasses. From this page you can scrap the required data as usual
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.flipkart.com/")

# %%
product=driver.find_element(By.CLASS_NAME,"Pke_EE")
product.send_keys('Sunglasses')

# %%
search_icon=driver.find_element(By.CLASS_NAME,"_2iLD__")
search_icon.click()

# %%
sunglasses_brand= []
sunglasses_description= []
sunglasses_price= []
sunglasses_discount=[]

# %%
start=0
end=3
for pages in range(start,end):
    #scraping brand name
    brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand_tags[0:100]:
        brand=i.text
        sunglasses_brand.append(brand)

# %%
start=0
end=3
for pages in range(start,end):
    #scraping product description
    description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in description_tags[0:100]:
        description=i.text
        sunglasses_description.append(description)

# %%
start=0
end=3
for pages in range(start,end):
    #scraping product price
    price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price_tags[0:100]:
        price=i.text
        sunglasses_price.append(price)

# %%
start=0
end=3
for pages in range(start,end):
    #scraping product discounted price
    discount_tags=driver.find_elements(By.XPATH,'//div[@class="_3I9_wc"]')
    for i in discount_tags[0:100]:
        discount=i.text
        sunglasses_discount.append(discount)

# %%
for i in range(100):
    print(f"Brand: {sunglasses_brand[i]},Description: {sunglasses_description[i]},Price: {sunglasses_price[i]},Discount: {sunglasses_discount[i]}")
# Out:
# Brand: ARICKS,Description: UV Protection, Toughened Glass Lens Retro Square Sungla...,Price: ₹381,Discount: ₹2,499
# Brand: VINCENT CHASE,Description: UV Protection Wayfarer Sunglasses (59),Price: ₹549,Discount: ₹1,999
# Brand: Elligator,Description: UV Protection Aviator, Wayfarer Sunglasses (54),Price: ₹156,Discount: ₹1,299
# Brand: RBGIIT,Description: Night Vision, UV Protection, Polarized Wrap-around Sung...,Price: ₹229,Discount: ₹599
# Brand: ROADWAY,Description: UV Protection Wayfarer, Sports, Spectacle , Retro Squar...,Price: ₹264,Discount: ₹1,299
# Brand: Ray-Ban,Description: Polarized Wayfarer Sunglasses (51),Price: ₹7,494,Discount: ₹12,490
# Brand: Shadehouse,Description: Mirrored, UV Protection Rectangular, Retro Square, Wayf...,Price: ₹599,Discount: ₹1,199
# Brand: I Flash,Description: UV Protection, Mirrored Wayfarer Sunglasses (54),Price: ₹217,Discount: ₹2,499
# ...

# %%
#Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link: https://www.flipkart.com/apple-iphone-11-black-64-gb/product- reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market place=FLIPKART
#As shown in the above page you have to scrape the tick marked attributes. These are:
#1. Rating2. Review summary 3. Full review  4. You have to scrape this data for first 100reviews
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART")

# %%
reviews = []

# %%
while len(reviews) < 100:
    # Find all review containers on the page using XPath
    review_containers = driver.find_elements(By.XPATH,'//div[@class="_27M-vq"]')

    for container in review_containers:
        # Extract rating, review summary, and full review using XPath
        rating = container.find_element(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]').text.strip()
        summary = container.find_element(By.XPATH,'//p[@class="_2-N8zT"]').text.strip()
        full_review = container.find_element(By.XPATH,'//div[@class="t-ZTKy"]').text.strip()

        # Append the extracted data to the reviews list
        reviews.append({
            'Rating': rating,
            'Review Summary': summary,
            'Full Review': full_review
        })

        # Break the loop if we have scraped 100 reviews
        if len(reviews) == 100:
            break

# %%
 # Scroll down to load more reviews
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# Print the scraped reviews data
for i, review in enumerate(reviews):
    print(f"Review {i+1}:")
    print(f"Rating: {review['Rating']}")
    print(f"Review Summary: {review['Review Summary']}")
    print(f"Full Review: {review['Full Review']}")
    print()

# Close the browser
driver.quit()
# Out:
# Review 1:
# Rating: 5
# Review Summary: Terrific
# Full Review: Very very good
#
# Review 2:
# Rating: 5
# Review Summary: Terrific
# Full Review: Very very good
#
# Review 3:
# Rating: 5
# Review Summary: Terrific
# Full Review: Very very good
#
# Review 4:
# Rating: 5
# Review Summary: Terrific
# Full Review: Very very good
#
# Review 5:
# Rating: 5
# Review Summary: Terrific
# Full Review: Very very good
#
# Review 6:
# Rating: 5
# Review Summary: Terrific
# Full Review: Very very good
#
# Review 7:
# Rating: 5
# Review Summary: Terrific
# Full Review: Very very good
#
# Review 8:
# Rating: 5
# Review Summary: Terrific
# Full Review: Very very good
#
# Review 9:
# Rating: 5
# Review Summary: Terrific
# Full Review: Very very good
#
# Review 10:
# Rating: 5
# Review Summary: Terrific
# Full Review: Very very good
#
# Review 11:
# Rating: 5
# Review Summary: Terrific
# Full Review: Very very good
#
# Review 12:
# Rating: 5
# Review Summary: Terrific
# Full Review: Very very good
#
# ...

# %%
#Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field.
#You have to scrape 3 attributes of each sneaker:
#1. Brand  2. Product Description  3. Price . As shown in the below image, you have to scrape the above attributes.
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome()

# %%
# Open Flipkart website and search for "sneakers"
driver.get("https://www.flipkart.com/")

# %%
search_box=driver.find_element(By.CLASS_NAME,"Pke_EE")
search_box.send_keys("sneakers")

# %%
search_button = driver.find_element(By.XPATH,"//button[@type='submit']")
search_button.click()

# %%
# Scrape data for the first 100 sneakers
sneakers_brand=[]
sneakers_description=[]
sneakers_price=[]

# %%
start=0
end=3
for pages in range(start,end):
    #scraping brand name
    brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand_tags[0:100]:
        brand=i.text
        sneakers_brand.append(brand)

# %%
start=0
end=3
for pages in range(start,end):
    #scraping product description
    description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in description_tags[0:100]:
        description=i.text
        sneakers_description.append(description)

# %%
start=0
end=3
for pages in range(start,end):
    #scraping product price
    price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price_tags[0:100]:
        price=i.text
        sneakers_price.append(price)

# %%
# Print the scraped sneakers data
for i in range(100):
    print(f"Brand: {sneakers_brand[i]},Description: {sneakers_description[i]},Price: {sneakers_price[i]}")
# Out:
# Brand: Magnolia,Description: Modern Trendy Sneakers boot Sneakers Sneakers For Men,Price: ₹388
# Brand: RapidBox,Description: Sneakers For Men,Price: ₹589
# Brand: asian,Description: Sneakers For Women,Price: ₹699
# Brand: asian,Description: Sneakers For Men,Price: ₹1,175
# Brand: BRUTON,Description: Combo Pack Of 4 Casual Shoes Loafer Shoes Sneakers For ...,Price: ₹499
# Brand: HRX by Hrithik Roshan,Description: Rerooted Classics Sneakers For Men,Price: ₹1,295
# Brand: ATOM,Description: Sneakers For Men,Price: ₹1,285
# Brand: BAUCHHAAR,Description: Sneakers For Men,Price: ₹499
# Brand: aadi,Description: Mesh| Lightweight| Premiun| Comfort| Summer Tendy| Outd...,Price: ₹279
# Brand: Sparx,Description: SL-170 Sneakers For Women,Price: ₹849
# Brand: Shozie,Description: Stylish Sneakers Shoes for Women And Girls Sneakers For...,Price: ₹499
# Brand: Footox,Description: Casual Shoe Sneakers For Women,Price: ₹599
# Brand: JACK & JONES,Description: Sneakers For Men,Price: ₹762
# ...

# %%
#Q7: Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon. Then set CPU Type filter to “Intel Core i7” as shown in the below image:
#After setting the filters scrape first 10 laptops data. You have to scrape 3 attributes for each laptop:
#1. Title  2. Ratings 3. Price
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.amazon.in/")

# %%
search_box = driver.find_element(By.XPATH, "//input[@id='twotabsearchtextbox']")
search_box.send_keys("Laptop")

# %%
search_button = driver.find_element(By.XPATH, "//input[@value='Go']")
search_button.click()

# %%
# Set CPU Type filter to "Intel Core i7"
cpu_filter = driver.find_element(By.XPATH, "/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/div[6]/span")
cpu_filter.click()

# %%
intel_core_i7_option = driver.find_element(By.XPATH, "/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[6]/span[9]/li/span/a/div/label/i")
intel_core_i7_option.click()

# %%
# Scrape data for the first 10 laptops
laptops_title = []
laptops_rating=[]
laptops_price=[]

# %%
#scraping laptops title
title_tags=driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
for i in title_tags[0:10]:
    title=i.text
    laptops_title.append(title)

# %%
#scraping laptop ratings
rating_tags=driver.find_elements(By.XPATH,'//span[@class="a-size-base puis-normal-weight-text"]')
for i in rating_tags[0:10]:
    rating=i.text
    laptops_rating.append(rating)

# %%
#scraping laptops price
price_tags=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in price_tags[0:10]:
    price=i.text
    laptops_price.append(price)

# %%
# Print the scraped sneakers data
for i in range(10):
    print(f"Title: {laptops_title[i]},  \nRatings:   {laptops_rating[i]}, \nPrice:   {laptops_price[i]}")
# Out:
# Title: Dell Inspiron 5430 Laptop, Intel Core i7-1360P Processor/ 16GB/ 1TB SSD/14.0" (35.56cm) FHD+ WVA AG with Comfortview 250 nits/Backlit KB + FPR/Win 11 + MSO'21/15 Month McAfee/Platinum Silver/ 1.59kg,
# Ratings:   3.3,
# Price:   86,490
# Title: ASUS Vivobook 15, Intel Core i7-12650H 12th Gen, 15.6" (39.62 cm) FHD, Thin and Light Laptop (16GB/512GB/Win11/Office 2021/Blue/1.7 kg), X1502ZA-EJ741WS,
# Ratings:   4.0,
# Price:   64,990
# Title: ASUS TUF Gaming F15, 15.6"(39.62 cms) FHD 144Hz, Intel Core i7-11800H 11th Gen, 4GB NVIDIA GeForce RTX 3050 Ti, Gaming Laptop (16GB/512GB SSD/Windows 11/90WHrs Battery/Black/2.30 Kg), FX506HE-HN382W,
# Ratings:   4.1,
# Price:   74,990
# Title: Acer Nitro 5 12th Gen Intel Core i7-12650H Gaming Laptop (Windows 11 Home/16 GB/1TB SSD/NVIDIA GeForce RTX 3070Ti Graphics/165Hz) AN515-58 with 15.6 inch QHD IPS Display, Killer WiFi 6, RGB Keyboard,
# Ratings:   4.1,
# Price:   99,990
# ...

# %%
#Q8: Write a python program to scrape data for Top 1000 Quotes of All Time.
#The above task will be done in following steps:1. First get the webpagehttps://www.azquotes.com/2. Click on Top Quotes 
#3. Than scrap a) Quote b) Author c) Type Of Quotes
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.azquotes.com/")

# %%
search_quotes= driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div/div[2]/div[1]/div/form/input[1]")
search_quotes.send_keys('Top Quotes')

# %%
search_button=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div/div[2]/div[1]/div/form/input[3]")
search_button.click()

# %%
#scraping quotes
top_quotes=[]
quote_author=[]
quotes_type=[]

# %%
#scraping QUOTES
quote_tags=driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in quote_tags:
    quote=i.text
    top_quotes.append(quote)

# %%
#scraping QUOTES AUTHOR
author_tags=driver.find_elements(By.XPATH,'//li[@class="first fl"]')
for i in author_tags:
    author=i.text
    quote_author.append(author)

# %%
#scraping QUOTES TYPE
qtype_tags=driver.find_elements(By.XPATH,'//section[@class="authors-page"]')
for i in qtype_tags:
    qtype=i.text
    quotes_type.append(qtype)

# %%
# Print the scraped sneakers data
for i in range(1000):
    print(f"Quote: {top_quotes[i]}, \nAuthor: {quote_author[i]}, \nType: {quotes_type[i]}")
# Out:
# Quote: TOP 25 INSPIRATIONAL QUOTES (of 1000) | A-Z Quotes,
# Author: A-Z Quotes › quotes › topics › inspirational,
# Type: A-Z Quotes › quotes › topics › inspirational
# Quote: ,
# Author: A-Z Quotes › author › 2136-Warren_Buffett,
# Type: A-Z Quotes › author › 2136-Warren_Buffett
# Quote: TOP 25 QUOTES BY WARREN BUFFETT (of 959) | A-Z Quotes,
# Author: A-Z Quotes › author › 4399-Albert_Einstein,
# Type: A-Z Quotes › author › 4399-Albert_Einstein
# Quote: ,
# Author: A-Z Quotes › author › 5308-Mahatma_Gandhi,
# Type: A-Z Quotes › author › 5308-Mahatma_Gandhi
# Quote: TOP 25 QUOTES BY ALBERT EINSTEIN (of 1952) | A-Z Quotes,
# Author: A-Z Quotes › author › 14530-Mother_Teresa,
# Type: A-Z Quotes › author › 14530-Mother_Teresa
# Quote: ,
# Author: A-Z Quotes › author › 10784-Isaac_Newton,
# Type: A-Z Quotes › author › 10784-Isaac_Newton
# Quote: TOP 25 QUOTES BY MAHATMA GANDHI (of 3171) | A-Z Quotes,
# Author: A-Z Quotes › author › 9365-Nelson_Mandela,
# ...

# %%
#Q9: Write a python program to display list of respected former Prime Ministers of India
#(i.e. Name, Born-Dead, Term of office, Remarks) from https://www.jagranjosh.com/.
#This task will be done in following steps:
#1. First get the webpagehttps://www.jagranjosh.com/
#2. Then You have to click on the GK option
#3. Then click on the List of all Prime Ministers of India
#4. Then scrap the mentioned data and make theDataFrame
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.jagranjosh.com/")

# %%
gk_link = driver.find_element(By.XPATH,'/html/body/div/header/nav/div/div/div[3]/ul/li[3]/a')
gk_link.click()

# %%
pm_link = driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a')
pm_link.click()

# %%
#Step 3: Click on the List of all Prime Ministers of India
pm_list = driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[1]/div/div/div/div[4]/span/div[3]')
pm_list.click()

# %%
#scrap data
data = []
rows = driver.find_elements(By.XPATH,'//div[@class="table-box"]')
for row in rows[1:]:  # Skipping the header row
    cols = row.find_elements(By.XPATH,'//div[@class="table-box"]')
    name = cols[1].text
    born_dead = cols[1].text
    term_of_office = cols[1].text
    remarks = cols[1].text
    data.append([name, born_dead, term_of_office, remarks])

# %%
# Create a DataFrame
df = pd.DataFrame(data, columns=['Name', 'Born-Dead', 'Term of Office', 'Remarks'])

# Print the DataFrame
print(df)
# Out:
#                                                 Name  \
# 0  List of all Presidents of India List of Nickna...
#
#                                            Born-Dead  \
# 0  List of all Presidents of India List of Nickna...
#
#                                       Term of Office  \
# 0  List of all Presidents of India List of Nickna...
#
#                                              Remarks
# 0  List of all Presidents of India List of Nickna...

# %%
# !pip install bs4
# !pip install requests
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Step 1: Get the webpage
url = "https://www.jagranjosh.com/"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

# Step 2: Click on the GK option (assuming it's a link)
gk_link = soup.find("a", text="GK")
gk_url = gk_link["href"]

# Step 3: Click on the List of all Prime Ministers of India
gk_response = requests.get(gk_url)
gk_soup = BeautifulSoup(gk_response.content, "html.parser")

prime_ministers_page = None

# Assuming there's a link with the text "List of all Prime Ministers of India"
prime_ministers_link = gk_soup.find("a", text="List of all Prime Ministers of India")
if prime_ministers_link:
    prime_ministers_page = prime_ministers_link["href"]

if prime_ministers_page:
    # Step 4: Scrap the data from the Prime Ministers page
    prime_ministers_url = prime_ministers_page
    prime_ministers_response = requests.get(prime_ministers_url)
    prime_ministers_soup = BeautifulSoup(prime_ministers_response.content, "html.parser")

    # Extract the required information and create a DataFrame
    pm_table = prime_ministers_soup.find("table")
    if pm_table:
        rows = pm_table.find_all("tr")
        data = []

        for row in rows[1:]:  # Skip the header row
            columns = row.find_all("td")
            if len(columns) >= 4:
                name = columns[0].text.strip()
                born_dead = columns[1].text.strip()
                term_of_office = columns[2].text.strip()
                remarks = columns[3].text.strip()
                data.append([name, born_dead, term_of_office, remarks])

        df = pd.DataFrame(data, columns=["Name", "Born-Dead", "Term of Office", "Remarks"])
        print(df)
    else:
        print("No Prime Ministers data found on the page.")
else:
    print("Link to List of Prime Ministers not found on the GK page.")
# Out:
# ...
#    Name                    Born-Dead Term of Office  \
# 0    1.            Jawahar Lal Nehru    (1889–1964)
# 1    2.    Gulzarilal Nanda (Acting)    (1898-1998)
# 2    3.          Lal Bahadur Shastri    (1904–1966)
# 3    4.  Gulzari Lal Nanda  (Acting)    (1898-1998)
# 4    5.                Indira Gandhi    (1917–1984)
# 5    6.                Morarji Desai    (1896–1995)
# 6    7.                 Charan Singh    (1902–1987)
# 7    8.                Indira Gandhi    (1917–1984)
# 8    9.                 Rajiv Gandhi    (1944–1991)
# 9   10.                  V. P. Singh    (1931–2008)
# 10  11.              Chandra Shekhar    (1927–2007)
# 11  12.          P. V. Narasimha Rao    (1921–2004)
# 12  13.         Atal Bihari Vajpayee   (1924- 2018)
# 13  14.             H. D. Deve Gowda    (born 1933)
# 14  15.           Inder Kumar Gujral    (1919–2012)
# 15  16.         Atal Bihari Vajpayee    (1924-2018)
# 16  17.               Manmohan Singh    (born 1932)
# ...

# %%
#Q10: Write a python program to display list of 50 Most expensive cars in the world (i.e. Car name and Price) from https://www.motor1.com/
#This task will be done in following steps:
#1. First get the webpage https://www.motor1.com/
#2. Then You have to type in the search bar ’50 most expensive cars’
#3. Then click on 50 most expensive cars in the world..
#4. Then scrap the mentioned data and make the dataframe.
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.motor1.com/")

# %%
# Step 2: Type in the search bar
search_bar = driver.find_element(By.XPATH,'/html/body/div[10]/div[2]/div/div/div[3]/div/div/div/form/input')
search_bar.send_keys("50 most expensive cars")

# %%
# Step 3: Click on 50 most expensive cars in the world
search_button = driver.find_element(By.XPATH,'/html/body/div[10]/div[2]/div/div/div[3]/div/div')
search_button.click()

# %%
# Step 4: Scrape the data
car_names = driver.find_elements(By.XPATH,'//span[@class="arrow-holder"]')
prices = driver.find_elements(By.XPATH,'/html/body/div[10]/div[7]/div[2]/div[1]/div[2]/div[2]/p[6]/strong')

# Create a list to store the data
data = []

# Extract car names and prices
for name, price in zip(car_names, prices):
    data.append({'Car Name': name.text, 'Price': price.text})

# Create a DataFrame
df = pd.DataFrame(data)

# Print the DataFrame
print(df)

# Close the webdriver
driver.quit()
# Out:
#               Car Name                Price
# 0  Aston Martin Valour  Price: $1.7 Million

# %%
# Step 4: Scrape the data
car_names = driver.find_elements(By.XPATH,'//span[@class="arrow-holder"]')
prices = driver.find_elements(By.XPATH,'/html/body/div[10]/div[7]/div[2]/div[1]/div[2]/div[2]/ul')

# Create a list to store the data
data = []

# Extract car names and prices
for name, price in zip(car_names, prices):
    data.append({'Car Name': name.text, 'Price': price.text})

# Create a DataFrame
df = pd.DataFrame(data)

# Print the DataFrame
print(df)

# Close the webdriver
driver.quit()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
